# %% [markdown]
# # Focussing on the Alcohol df from WHO
# - only for indicator: Total alcohol per capita (>= 15 years of age) consumption (litres of pure alcohol)
# - covering multiple years, mutliple contries
# - downloaded from: https://data.who.int/indicators/i/EF38E6A/EE6F72A

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\ThinkPad\Desktop\Mastermind\WHO\WHO_health_indicators\Alcohol_only.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5405 entries, 0 to 5404
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   IND_ID                  5405 non-null   str
#  1   IND_CODE                5405 non-null   str
#  2   IND_UUID                5405 non-null   str
#  3   IND_PER_CODE            5405 non-null   str
#  4   DIM_TIME                5405 non-null   int64
#  5   DIM_TIME_TYPE           5405 non-null   str
#  6   DIM_GEO_CODE_M49        5405 non-null   int64
#  7   DIM_GEO_CODE_TYPE       5405 non-null   str
#  8   DIM_PUBLISH_STATE_CODE  5405 non-null   str
#  9   IND_NAME                5405 non-null   str
#  10  GEO_NAME_SHORT          5382 non-null   str
#  11  DIM_SEX                 5405 non-null   str
#  12  RATE_PER_CAPITA_N       5405 non-null   float64
#  13  RATE_PER_CAPITA_NL      5405 non-null   float64
#  14  RATE_PER_CAPITA_NU      5405 non-null   float64
# dtypes: float64(3), int64(2), str(10)
# memory usage: 633.5 KB
