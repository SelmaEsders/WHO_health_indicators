# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\vesna\Desktop\Neuefische\MyWork\WHO\WHO_health_indicators\WHS2025_DATADOWNLOAD.csv')
df.head()
# Out:
#                                        IndicatorName   IndicatorCode  \
# 0  Adolescent birth rate (per 1000 women aged 10-...  MDG_0000000003
# 1  Adolescent birth rate (per 1000 women aged 10-...  MDG_0000000003
# 2  Adolescent birth rate (per 1000 women aged 10-...  MDG_0000000003
# 3  Adolescent birth rate (per 1000 women aged 10-...  MDG_0000000003
# 4  Adolescent birth rate (per 1000 women aged 10-...  MDG_0000000003
#
#               Location LocationCode  Year       Disaggregation  NumericValue  \
# 0          Afghanistan          AFG  2021  AGEGROUP_YEARS10-14     18.000000
# 1       African Region          AFR  2024  AGEGROUP_YEARS10-14      2.991000
# 2              Albania          ALB  2022  AGEGROUP_YEARS10-14      0.210000
# 3              Andorra          AND  2020  AGEGROUP_YEARS10-14      0.000000
# 4  Antigua and Barbuda          ATG  2020  AGEGROUP_YEARS10-14      0.307977
#
#   DisplayValue                                           Comments
# 0         18.0  Afghanistan 2022-2023 Multiple Indicator Clust...
# 1         2.99                                                NaN
# 2          0.2                              Registration Eurostat
# 3            0         Registration National Statistics & WPP2024
# 4          0.3         Registration National Statistics & WPP2024

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9729 entries, 0 to 9728
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   IndicatorName   9729 non-null   str
#  1   IndicatorCode   9729 non-null   str
#  2   Location        9729 non-null   str
#  3   LocationCode    9729 non-null   str
#  4   Year            9729 non-null   str
#  5   Disaggregation  1517 non-null   str
#  6   NumericValue    9665 non-null   float64
#  7   DisplayValue    9727 non-null   str
#  8   Comments        2722 non-null   str
# dtypes: float64(1), str(8)
# memory usage: 684.2 KB

# %%
df["IndicatorName"].value_counts()
# Out:
# IndicatorName
# Healthy life expectancy at birth (years)                                                                                                                                                   576
# Life expectancy at birth (years)                                                                                                                                                           576
# Tuberculosis incidence (per 100 000 population)                                                                                                                                            205
# Road traffic mortality rate (per 100 000 population)                                                                                                                                       204
# Annual mean concentrations of fine particulate matter (PM2.5) in cities (µg/m3)                                                                                                            202
# Diphtheria-tetanus-pertussis (DTP3) immunization coverage among 1-year-olds (%)                                                                                                            202
# Hepatitis B surface antigen (HBsAg) prevalence among children under 5 years (%)                                                                                                            202
# Maternal mortality ratio (per 100 000 live births)                                                                                                                                         202
# Neonatal mortality rate (per 1000 live births)                                                                                                                                             202
# Under-five mortality rate (per 1000 live births)                                                                                                                                           202
# Average of 15 International Health Regulations core capacity scores                                                                                                                        201
# New HIV infections (per 1000 uninfected population)                                                                                                                                        201
# Prevalence of anaemia in women of reproductive age (15-49 years) (%)                                                                                                                       201
# Proportion of population with primary reliance on clean fuels and technology (%)                                                                                                           201
# Reported number of people requiring interventions against NTDs                                                                                                                             201
# UHC: Service coverage index                                                                                                                                                                201
# Domestic general government health expenditure (GGHE-D) as percentage of general government expenditure (GGE) (%)                                                                          200
# Density of nursing and midwifery personnel (per 10 000 population)                                                                                                                         199
# Measles-containing-vaccine second-dose (MCV2) immunization coverage by the locally recommended age (%)                                                                                     197
# Density of medical doctors (per 10 000 population)                                                                                                                                         196
# Total alcohol per capita (≥ 15 years of age) consumption (litres of pure alcohol)                                                                                                          195
# Density of dentists (per 10 000 population)                                                                                                                                                192
# Mortality rate due to homicide (per 100 000 population)                                                                                                                                    192
# Mortality rate from unintentional poisoning (per 100 000 population)                                                                                                                       192
# Probability of dying from any of CVD, cancer, diabetes, CRD between age 30 and exact age 70 (%)                                                                                            192
# Suicide mortality rate (per 100 000 population)                                                                                                                                            192
# Mortality rate attributed to exposure to unsafe WASH services (per 100 000 population)                                                                                                     190
# Age-standardized mortality rate attributed to household and ambient air pollution  (per 100 000 population)                                                                                187
# Density of pharmacists (per 10 000 population)                                                                                                                                             183
# Adolescent birth rate (per 1000 women aged 15-19 years)                                                                                                                                    182
# Proportion of births attended by skilled health personnel (%)                                                                                                                              180
# Age-standardized prevalence of tobacco use among persons 15 years and older  (%)                                                                                                           172
# Prevalence of overweight in children under 5 (%)                                                                                                                                           169
# Prevalence of stunting in children under 5 (%)                                                                                                                                             168
# Pneumococcal conjugate 3rd dose (PCV3) immunization coverage  among 1-year olds (%)                                                                                                        165
# Proportion of ever-partnered women and girls aged 15 years and older subjected to physical and/or sexual violence by a current or former intimate partner in the previous 12 months (%)    163
# Adolescent birth rate (per 1000 women aged 10-14 years)                                                                                                                                    161
# Proportion of ever-partnered women and girls aged 15-49 years subjected to physical and/or sexual violence by a current or former intimate partner in their lifetime (%)                   158
# Total net official development assistance to medical research and basic health sectors per capita (US$), by recipient country                                                              145
# Amount of water- and sanitation-related official development assistance that is part of a government-coordinated spending plan (constant 2020 US$ millions)                                142
# Proportion of safely treated domestic wastewater flows (%)                                                                                                                                 141
# Human papillomavirus (HPV) immunization coverage estimates among primary target cohort (9-14 years old girls) (%                                                                           139
# Prevalence of wasting in children under 5 (%)                                                                                                                                              135
# Proportion of population using safely-managed sanitation services (%)                                                                                                                      132
# Proportion of population using safely-managed drinking-water services (%)                                                                                                                  128
# Population with household expenditures on health > 10% of total household expenditure or income (%)                                                                                        125
# Population with household expenditures on health > 25% of total household expenditure or income (%)                                                                                        125
# Proportion of women of reproductive age who have their need for family planning satisfied with modern methods (%)                                                                          112
# Malaria incidence (per 1000 population at risk)                                                                                                                                            104
# Proportion of population using a hand-washing facility with soap and water (%)                                                                                                              87
# Percentage of bloodstream infections due methicillin-resistant Staphylococcus aureus (%)                                                                                                    86
# Percentage of bloodstream infection due to Escherichia coli resistant to 3rd-generation cephalosporin (%)                                                                                   85
# Proportion of health facilities with a core set of relevant essential medicines available and affordable on a sustainable basis (%)                                                         17
# Contact coverage of treatment services for drug use disorders (%)                                                                                                                           16
# Contact coverage of treatment services for alcohol use disorders (%)                                                                                                                         6
# Name: count, dtype: int64

# %%
df["IndicatorName"].value_counts().sum()
# Out:
# np.int64(9729)

# %%
df["IndicatorName"].nunique()
# Out:
# 55

# %%
indicator_list= df["IndicatorName"].unique()
indicator_list = pd.DataFrame(indicator_list, columns=["IndicatorName"])
indicator_list.to_csv("indicator_list.csv", index=False)
